# %%
# Block 1: Load Train Dataset
import face_recognition
import os

train_dir = 'dataset/train'
known_encodings = []
known_names = []

print("[INFO] Encoding faces from train/ folder...")

for person_name in os.listdir(train_dir):
    person_path = os.path.join(train_dir, person_name)
    if not os.path.isdir(person_path):
        continue

    for img_name in os.listdir(person_path):
        img_path = os.path.join(person_path, img_name)
        image = face_recognition.load_image_file(img_path)
        encodings = face_recognition.face_encodings(image)

        if encodings:
            known_encodings.append(encodings[0])
            known_names.append(person_name)

print(f"[INFO] Loaded {len(known_encodings)} face encodings from train/ dataset.")
# Out:
# [INFO] Encoding faces from train/ folder...
# [INFO] Loaded 4125 face encodings from train/ dataset.

# %%
import cv2
from datetime import datetime
import csv

attendance = {}

# Initialize webcam
video = cv2.VideoCapture(0)
if not video.isOpened():
    print("Error: Could not open video stream.")
    exit()

print("[INFO] Starting attendance system... Press 'q' to quit")

while True:
    ret, frame = video.read()
    if not ret:
        break

    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)
    rgb_small_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

    face_locations = face_recognition.face_locations(rgb_small_frame)
    face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

    for encoding, location in zip(face_encodings, face_locations):
        distances = face_recognition.face_distance(known_encodings, encoding)
        min_distance = min(distances) if len(distances) > 0 else 1.0

        if min_distance < 0.45:
            match_index = distances.tolist().index(min_distance)
            name = known_names[match_index]
        else:
            name = "Unknown"

        # Do not save attendance for Unknown faces
        if name != "Unknown" and name not in attendance:
            timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            attendance[name] = timestamp
            print(f"{name} marked present at {timestamp}")
        
        # Draw box and name (label unknown faces as 'Unknown')
        top, right, bottom, left = [v * 4 for v in location]
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
        cv2.putText(frame, name, (left, top - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

    cv2.imshow("AI Attendance System", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()

# Save attendance (only for recognized faces, no unknown faces)
with open("attendance.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Name", "Timestamp"])
    for name, timestamp in attendance.items():
        writer.writerow([name, timestamp])

print("✅ Attendance saved to attendance.csv")
# Out:
# [INFO] Starting attendance system... Press 'q' to quit
# Keshav Bansal marked present at 2025-05-08 09:52:23
# Bhavya Mittal marked present at 2025-05-08 09:52:34
# Dharmpreet marked present at 2025-05-08 09:52:56
# ✅ Attendance saved to attendance.csv

# %%
# Block 3: Capture unknown faces, ask for name, and split into train/test

import os
import cv2
import face_recognition
from datetime import datetime
import random

# Parameters
dataset_train_dir = "dataset/train"
dataset_test_dir = "dataset/test"
os.makedirs(dataset_train_dir, exist_ok=True)
os.makedirs(dataset_test_dir, exist_ok=True)

max_unknown_images = 100
saved_count = 0
tolerance = 0.5  # for matching

# Start webcam
video = cv2.VideoCapture(0)
if not video.isOpened():
    print("Error: Could not open webcam.")
    exit()

print(" Capturing faces... Press 'q' to stop manually.")

# Ask for the name once
person_name = input("Enter the name for the captured faces (or type 'Unknown'): ").strip()

# Create folders if not exist
train_person_dir = os.path.join(dataset_train_dir, person_name)
test_person_dir = os.path.join(dataset_test_dir, person_name)
os.makedirs(train_person_dir, exist_ok=True)
os.makedirs(test_person_dir, exist_ok=True)

while saved_count < max_unknown_images:
    ret, frame = video.read()
    if not ret:
        break

    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)
    rgb_small_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

    face_locations = face_recognition.face_locations(rgb_small_frame)
    face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

    for encoding, location in zip(face_encodings, face_locations):
        matches = face_recognition.compare_faces(known_encodings, encoding, tolerance=tolerance)

        if not any(matches):
            top, right, bottom, left = [coord * 4 for coord in location]
            face_img = frame[top:bottom, left:right]

            if face_img.size > 0:
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
                filename = f"{person_name}_{saved_count + 1}_{timestamp}.jpg"

                # Decide randomly: 80% Train, 20% Test
                if random.random() < 0.8:
                    save_path = os.path.join(train_person_dir, filename)
                else:
                    save_path = os.path.join(test_person_dir, filename)

                cv2.imwrite(save_path, face_img)
                print(f"📸 Saved: {save_path}")
                saved_count += 1

                # Draw box
                cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)
                cv2.putText(frame, f"{person_name} {saved_count}", (left, top - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0, 0, 255), 2)

                if saved_count >= max_unknown_images:
                    break

    cv2.imshow("Capturing Faces", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("🛑 Stopped manually.")
        break

video.release()
cv2.destroyAllWindows()

print(f"✅ Finished. {saved_count} images saved for '{person_name}' into Train/Test folders!")
# Out:
# 🔍 Capturing faces... Press 'q' to stop manually.
# 🛑 Stopped manually.
# ✅ Finished. 0 images saved for 'abc' into Train/Test folders!

# %%
# Block 4: Accuracy Checker (including Unknown faces)
import os
import face_recognition

test_dir = 'dataset/test'
total_tests = 0
correct_predictions = 0
unknown_correct = 0
unknown_total = 0

print("[INFO] Testing faces from test/ folder...")

for person_name in os.listdir(test_dir):
    person_path = os.path.join(test_dir, person_name)
    if not os.path.isdir(person_path):
        continue

    for img_name in os.listdir(person_path):
        img_path = os.path.join(person_path, img_name)
        image = face_recognition.load_image_file(img_path)
        encodings = face_recognition.face_encodings(image)

        if not encodings:
            continue

        total_tests += 1
        encoding = encodings[0]

        distances = face_recognition.face_distance(known_encodings, encoding)
        min_distance = min(distances) if len(distances) > 0 else 1.0

        if min_distance < 0.45:
            match_index = distances.tolist().index(min_distance)
            predicted_name = known_names[match_index]
        else:
            predicted_name = "Unknown"

        if person_name == "Unknown":
            unknown_total += 1
            if predicted_name == "Unknown":
                unknown_correct += 1

        if predicted_name == person_name:
            correct_predictions += 1
        else:
            print(f"Wrong: Expected '{person_name}', but got '{predicted_name}' for image {img_name}")


accuracy = (correct_predictions / total_tests) * 100 if total_tests > 0 else 0
unknown_accuracy = (unknown_correct / unknown_total) * 100 if unknown_total > 0 else 0

print(f"\nAccuracy (known faces): {accuracy:.2f}% ({correct_predictions}/{total_tests} correct)")
print(f"Unknown Accuracy: {unknown_accuracy:.2f}% ({unknown_correct}/{unknown_total} correct)")
# Out:
# [INFO] Testing faces from test/ folder...
# Wrong: Expected 'pins_Adriana Lima', but got 'pins_camila mendes' for image Adriana Lima109_11.jpg
# Wrong: Expected 'pins_Adriana Lima', but got 'Unknown' for image Adriana Lima111_14.jpg
# Wrong: Expected 'pins_Adriana Lima', but got 'Unknown' for image Adriana Lima113_16.jpg
# Wrong: Expected 'pins_Adriana Lima', but got 'Unknown' for image Adriana Lima116_19.jpg
# Wrong: Expected 'pins_Alex Lawther', but got 'Unknown' for image Alex Lawther148_36.jpg
# Wrong: Expected 'pins_Alex Lawther', but got 'Unknown' for image Alex Lawther148_37.jpg
# Wrong: Expected 'pins_Alex Lawther', but got 'Unknown' for image Alex Lawther148_38.jpg
# Wrong: Expected 'pins_Alex Lawther', but got 'Unknown' for image Alex Lawther149_39.jpg
# Wrong: Expected 'pins_Alvaro Morte', but got 'Unknown' for image Alvaro Morte141_178.jpg
# Wrong: Expected 'pins_alycia dabnem carey', but got 'Unknown' for image alycia dabnem carey115_17.jpg
# Wrong: Expected 'pins_Amanda Crew', but got 'Unknown' for image Amanda Crew161_39.jpg
# Wrong: Expected 'pins_amber heard', but got 'Unknown' for image amber heard96_425.jpg
# Wrong: Expected 'pins_Andy Samberg', but got 'Unknown' for image Andy Samberg100_432.jpg
# Wrong: Expected 'pins_Andy Samberg', but got 'Unknown' for image Andy Samberg99_626.jpg
# Wrong: Expected 'pins_Anne Hathaway', but got 'Unknown' for image Anne Hathaway107_302.jpg
# Wrong: Expected 'pins_Avril Lavigne', but got 'Unknown' for image Avril Lavigne132_586.jpg
# Wrong: Expected 'pins_barack obama', but got 'Unknown' for image barack obama175_670.jpg
# Wrong: Expected 'pins_barbara palvin', but got 'Unknown' for image barbara palvin124_769.jpg
# Wrong: Expected 'pins_barbara palvin', but got 'Unknown' for image barbara palvin127_773.jpg
# Wrong: Expected 'pins_Ben Affleck', but got 'Unknown' for image Ben Affleck153_158.jpg
# Wrong: Expected 'pins_Ben Affleck', but got 'Unknown' for image Ben Affleck168_165.jpg
# Wrong: Expected 'pins_Bill Gates', but got 'Unknown' for image Bill Gates165_529.jpg
# Wrong: Expected 'pins_Bill Gates', but got 'Unknown' for image Bill Gates169_531.jpg
# Wrong: Expected 'pins_Bill Gates', but got 'Unknown' for image Bill Gates176_532.jpg
# Wrong: Expected 'pins_Bill Gates', but got 'Unknown' for image Bill Gates179_535.jpg
# Wrong: Expected 'pins_Bobby Morley', but got 'Unknown' for image Bobby Morley128_274.jpg
# Wrong: Expected 'pins_Bobby Morley', but got 'Unknown' for image Bobby Morley131_276.jpg
# Wrong: Expected 'pins_Bobby Morley', but got 'Unknown' for image Bobby Morley142_285.jpg
# Wrong: Expected 'pins_Bobby Morley', but got 'Unknown' for image Bobby Morley150_290.jpg
# Wrong: Expected 'pins_Brenton Thwaites', but got 'Unknown' for image Brenton Thwaites104_735.jpg
# Wrong: Expected 'pins_Brenton Thwaites', but got 'Unknown' for image Brenton Thwaites116_746.jpg
# Wrong: Expected 'pins_Brenton Thwaites', but got 'Unknown' for image Brenton Thwaites96_933.jpg
# Wrong: Expected 'pins_Brenton Thwaites', but got 'Unknown' for image Brenton Thwaites99_936.jpg
# Wrong: Expected 'pins_Brian J. Smith', but got 'Unknown' for image Brian J. Smith219_665.jpg
# Wrong: Expected 'pins_Brian J. Smith', but got 'Unknown' for image Brian J. Smith224_668.jpg
# Wrong: Expected 'pins_Brie Larson', but got 'Unknown' for image Brie Larson102_942.jpg
# Wrong: Expected 'pins_camila mendes', but got 'Unknown' for image camila mendes124_967.jpg
# Wrong: Expected 'pins_Chris Evans', but got 'Unknown' for image Chris Evans104_1115.jpg
# Wrong: Expected 'pins_Chris Evans', but got 'Unknown' for image Chris Evans113_1122.jpg
# Wrong: Expected 'pins_Chris Evans', but got 'Unknown' for image Chris Evans122_1128.jpg
# Wrong: Expected 'pins_Chris Evans', but got 'Unknown' for image Chris Evans99_1276.jpg
# Wrong: Expected 'pins_Chris Hemsworth', but got 'Unknown' for image Chris Hemsworth127_399.jpg
# Wrong: Expected 'pins_Chris Hemsworth', but got 'Unknown' for image Chris Hemsworth150_412.jpg
# Wrong: Expected 'pins_Chris Pratt', but got 'Unknown' for image Chris Pratt109_734.jpg
# Wrong: Expected 'pins_Chris Pratt', but got 'Unknown' for image Chris Pratt114_740.jpg
# Wrong: Expected 'pins_Chris Pratt', but got 'Unknown' for image Chris Pratt132_751.jpg
# Wrong: Expected 'pins_Christian Bale', but got 'Unknown' for image Christian Bale133_566.jpg
# Wrong: Expected 'pins_Cristiano Ronaldo', but got 'Unknown' for image Cristiano Ronaldo205_1323.jpg
# Wrong: Expected 'pins_Cristiano Ronaldo', but got 'Unknown' for image Cristiano Ronaldo209_1326.jpg
# Wrong: Expected 'pins_Cristiano Ronaldo', but got 'Unknown' for image Cristiano Ronaldo226_1333.jpg
# Wrong: Expected 'pins_Danielle Panabaker', but got 'Unknown' for image Danielle Panabaker129_1402.jpg
# Wrong: Expected 'pins_Dominic Purcell', but got 'Unknown' for image Dominic Purcell140_924.jpg
# Wrong: Expected 'pins_Dominic Purcell', but got 'Unknown' for image Dominic Purcell153_930.jpg
# Wrong: Expected 'pins_Dominic Purcell', but got 'Unknown' for image Dominic Purcell186_941.jpg
# Wrong: Expected 'pins_Eliza Taylor', but got 'Unknown' for image Eliza Taylor138_727.jpg
# Wrong: Expected 'pins_Eliza Taylor', but got 'Unknown' for image Eliza Taylor145_732.jpg
# Wrong: Expected 'pins_Eliza Taylor', but got 'Unknown' for image Eliza Taylor153_738.jpg
# Wrong: Expected 'pins_Eliza Taylor', but got 'Unknown' for image Eliza Taylor158_741.jpg
# Wrong: Expected 'pins_Elizabeth Lail', but got 'Unknown' for image Elizabeth Lail131_1079.jpg
# Wrong: Expected 'pins_elizabeth olsen', but got 'Unknown' for image elizabeth olsen94_1327.jpg
# Wrong: Expected 'pins_elizabeth olsen', but got 'Unknown' for image elizabeth olsen95_1328.jpg
# Wrong: Expected 'pins_ellen page', but got 'Unknown' for image ellen page119_1350.jpg
# Wrong: Expected 'pins_elon musk', but got 'Unknown' for image elon musk165_1561.jpg
# Wrong: Expected 'pins_elon musk', but got 'Unknown' for image elon musk170_1563.jpg
# Wrong: Expected 'pins_elon musk', but got 'Unknown' for image elon musk188_1571.jpg
# Wrong: Expected 'pins_Emilia Clarke', but got 'Unknown' for image Emilia Clarke103_867.jpg
# Wrong: Expected 'pins_Emilia Clarke', but got 'Unknown' for image Emilia Clarke108_871.jpg
# Wrong: Expected 'pins_Emilia Clarke', but got 'Unknown' for image Emilia Clarke114_877.jpg
# Wrong: Expected 'pins_Emilia Clarke', but got 'Unknown' for image Emilia Clarke95_1069.jpg
# Wrong: Expected 'pins_Emma Stone', but got 'Unknown' for image Emma Stone103_1704.jpg
# Wrong: Expected 'pins_Emma Stone', but got 'Unknown' for image Emma Stone109_1707.jpg
# Wrong: Expected 'pins_Emma Stone', but got 'Unknown' for image Emma Stone138_1716.jpg
# Wrong: Expected 'pins_Emma Stone', but got 'Unknown' for image Emma Stone93_1838.jpg
# Wrong: Expected 'pins_Emma Watson', but got 'Unknown' for image Emma Watson107_1849.jpg
# Wrong: Expected 'pins_Emma Watson', but got 'Unknown' for image Emma Watson117_1855.jpg
# Wrong: Expected 'pins_Emma Watson', but got 'Unknown' for image Emma Watson119_1856.jpg
# Wrong: Expected 'pins_gal gadot', but got 'Unknown' for image gal gadot106_1666.jpg
# Wrong: Expected 'pins_gal gadot', but got 'Unknown' for image gal gadot116_1675.jpg
# Wrong: Expected 'pins_gal gadot', but got 'Unknown' for image gal gadot123_1680.jpg
# Wrong: Expected 'pins_Gwyneth Paltrow', but got 'Unknown' for image Gwyneth Paltrow114_2071.jpg
# Wrong: Expected 'pins_Gwyneth Paltrow', but got 'Unknown' for image Gwyneth Paltrow116_2073.jpg
# Wrong: Expected 'pins_Gwyneth Paltrow', but got 'Unknown' for image Gwyneth Paltrow125_2081.jpg
# Wrong: Expected 'pins_Henry Cavil', but got 'Unknown' for image Henry Cavil125_1099.jpg
# Wrong: Expected 'pins_Henry Cavil', but got 'Unknown' for image Henry Cavil126_1100.jpg
# Wrong: Expected 'pins_Hugh Jackman', but got 'Unknown' for image Hugh Jackman142_1301.jpg
# Wrong: Expected 'pins_Inbar Lavi', but got 'Unknown' for image Inbar Lavi144_1476.jpg
# Wrong: Expected 'pins_Inbar Lavi', but got 'Unknown' for image Inbar Lavi147_1477.jpg
# Wrong: Expected 'pins_Jake Mcdorman', but got 'Unknown' for image Jake Mcdorman107_1217.jpg
# Wrong: Expected 'pins_Jake Mcdorman', but got 'Unknown' for image Jake Mcdorman113_1221.jpg
# Wrong: Expected 'pins_Jake Mcdorman', but got 'Unknown' for image Jake Mcdorman132_1234.jpg
# Wrong: Expected 'pins_Jason Momoa', but got 'Unknown' for image Jason Momoa113_2413.jpg
# Wrong: Expected 'pins_Jason Momoa', but got 'Unknown' for image Jason Momoa125_2424.jpg
# Wrong: Expected 'pins_jeff bezos', but got 'Unknown' for image jeff bezos228_2099.jpg
# Wrong: Expected 'pins_Jennifer Lawrence', but got 'Unknown' for image Jennifer Lawrence133_1613.jpg
# Wrong: Expected 'pins_Jennifer Lawrence', but got 'Unknown' for image Jennifer Lawrence135_1614.jpg
# Wrong: Expected 'pins_Jennifer Lawrence', but got 'Unknown' for image Jennifer Lawrence135_1615.jpg
# Wrong: Expected 'pins_Jennifer Lawrence', but got 'Unknown' for image Jennifer Lawrence135_1616.jpg
# Wrong: Expected 'pins_Jennifer Lawrence', but got 'Unknown' for image Jennifer Lawrence135_1617.jpg
# Wrong: Expected 'pins_Jeremy Renner', but got 'Unknown' for image Jeremy Renner121_2605.jpg
# Wrong: Expected 'pins_Jeremy Renner', but got 'Unknown' for image Jeremy Renner95_2754.jpg
# Wrong: Expected 'pins_Jessica Barden', but got 'Unknown' for image Jessica Barden129_1398.jpg
# Wrong: Expected 'pins_Jessica Barden', but got 'Unknown' for image Jessica Barden146_1418.jpg
#
# Accuracy (known faces): 90.61% (984/1086 correct)
# Unknown Accuracy: 100.00% (64/64 correct)
